# %% [markdown]
# # **Decision Tree**
#
# Build a tree that correctly classifies data and generalizes well

# %% [markdown]
# ## **Pseudo Code**

# %% [raw]
# function DTL(examples, attributes, default): returns a decision tree
#     if examples is empty then return default
#     else if all examples have the same classification then return the classification
#     else if attributes is empty then return MODE(examples)
#     else
#         best = CHOOSE-ATTRIBUTE(attributes, examples)
#         tree = a new decision tree with root test best
#
#         for each value v_i of best do:
#             examples_i = {elements of examples where best = v_i}
#             subtree =  DTL(examples_i, attributes - best, MODE(examples))
#
#             add a branch to tree with label v_i and subtree subtree
#         return tree

# %% [markdown]
# ## **Simple Example**

# %%
# Example dataset
X = [[2, 3], [1, 1], [3, 2], [6, 5], [7, 7], [8, 6]]
y = ['A', 'A', 'A', 'B', 'B', 'B']

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print(f"Accuracy : {accuracy_score(y_test, y_pred)}")
# Out:
# Accuracy : 1.0

# %% [markdown]
# ### **with cross-validation**

# %%
scores = cross_val_score(model, X, y, cv=3)

print(f"Accuracy for wach fold : {scores}")
print(f"Accuracy : {scores.mean()}")
# Out:
# Accuracy for wach fold : [1. 1. 1.]
# Accuracy : 1.0
