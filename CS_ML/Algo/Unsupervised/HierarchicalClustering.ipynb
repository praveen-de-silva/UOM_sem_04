# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(42)  # for reproducibility

df = pd.DataFrame(
    data={
        'x': [
            0, 1.1, 1, 2, 2, 4, 5, 5,
            0.5, 1.3, 1.8, 2.2, 2.5, 3.8, 4.2, 4.9,
            0.2, 1.0, 1.5, 2.1, 2.7, 3.5, 4.7, 5.0,
            0.3, 1.2, 1.7, 2.3, 2.9, 3.9, 4.1, 4.8,
            0.6, 1.4, 1.9, 2.4, 2.6, 3.6, 4.3, 4.6,
            0.1, 1.6, 1.2, 2.8, 2.0, 3.7, 4.4, 4.5,
            0.7, 1.8, 1.3, 2.6, 2.2, 3.4, 4.9, 5.0,
            0.4, 1.1, 1.9, 2.7, 2.3, 3.3, 4.0, 4.7,
            0.8, 1.5, 1.6, 2.5, 2.1, 3.2, 4.6, 4.8,
            0.9, 1.7, 1.4, 2.9, 2.4, 3.1, 4.5, 4.9,
            0.2, 1.3, 1.8, 2.0, 2.6, 3.0, 4.2, 4.4,
            0.5, 1.9, 1.1, 2.8
        ],
        'y': [
            0, 1.5, 4, 2, 3, 1, 0, 4,
            0.8, 1.7, 3.5, 2.1, 3.2, 1.2, 0.5, 3.8,
            0.3, 1.2, 3.8, 2.4, 3.0, 1.5, 0.2, 4.0,
            0.6, 1.4, 3.2, 2.3, 3.4, 1.1, 0.7, 3.9,
            0.9, 1.6, 3.6, 2.2, 3.1, 1.3, 0.4, 3.7,
            0.1, 1.8, 3.3, 2.5, 3.6, 1.0, 0.6, 3.5,
            0.7, 1.9, 3.1, 2.6, 3.3, 1.4, 0.3, 3.8,
            0.2, 1.3, 3.7, 2.7, 3.2, 1.6, 0.5, 3.6,
            0.4, 1.5, 3.4, 2.8, 3.5, 1.7, 0.8, 3.9,
            0.6, 1.7, 3.0, 2.9, 3.7, 1.8, 0.9, 4.0,
            0.3, 1.6, 3.2, 2.1, 3.4, 1.9, 0.2, 3.3,
            0.5, 1.8, 3.6, 2.4
        ]
    }
)

df
# Out:
#       x    y
# 0   0.0  0.0
# 1   1.1  1.5
# 2   1.0  4.0
# 3   2.0  2.0
# 4   2.0  3.0
# ..  ...  ...
# 87  4.4  3.3
# 88  0.5  0.5
# 89  1.9  1.8
# 90  1.1  3.6
# 91  2.8  2.4
#
# [92 rows x 2 columns]

# %%
plt.scatter(df.x, df.y)
